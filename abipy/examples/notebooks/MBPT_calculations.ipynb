# %% [markdown]
# # Postprocessing tools for Many-Body calculations with ABINIT

# %% [markdown]
# The $GW$ code saves the results of the calculation in the `SIGRES.nc` file produced at the end of the `SIGMA` run (`optdriver` 4).
# The Bethe-Salpeter code saves the optical spectra in the `MDF.nc` file.
# In this notebook, we will explain how to use `abipy` and `matplotlib` to visualize the results produce by the Many-Body code ($GW% and Bethe-Salpeter).
# Let's start by importing the basic modules we'll use for this tutorial.

# %%
# Use this at the beginning of your script so that your code is ready for python3
from __future__ import division, print_function, unicode_literals

import abipy.data as abidata

from abipy import abilab
from abipy.abilab import abiopen

# This line configures matplotlib to show figures embedded in the notebook, instead of poping up a new window. 
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## How to visualize QP corrections

# %%
sigma_file = abiopen(abidata.ref_file("tgw1_9o_DS4_SIGRES.nc"))

# Plot the KS energies with markers whose size is proportional to the difference E_GW - E_KS 
# Multiply the difference by 1000 to make the markers more visible.
figure = sigma_file.plot_ksbands_with_qpmarkers(qpattr="qpeme0", fact=1000)
# Out:
# ksampling {'kptopt': None, 'shifts': None, 'kptrlatt': None, 'mpdivs': None}
# old_fermie 6.2361626516, new fermie 5.95110732504
# /Users/gmatteo/Coding/git_branches/abipy/abipy/electrons/ebands.py:2041: UserWarning: warning scheme is None, occopt 1
#   warnings.warn("warning scheme is None, occopt %s" % occopt)

# %%
qplist_spin = sigma_file.qplist_spin
figure = qplist_spin[0].plot_qps_vs_e0(title="QPState corrections of Si", exclude_fields="vUme")
# Out:
# /Users/gmatteo/VENV-2.7/lib/python2.7/site-packages/numpy/core/numeric.py:462: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
# Printout of the QPState results
sigma_file.print_qps()
# Out:
# kpoint: [-0.250, -0.250, 0.000], weight = 0.000000, spin: 0, energy units: eV (NB: bands start from zero)
# band      e0          qpe  qpe_diago   vxcme  sigxme     sigcmee0  vUme   ze0      qpeme0
# 0      -5.05  -4.76-0.01j      -4.56  -10.49  -16.55   6.54-0.02j  0.00  0.59  0.29-0.01j
# 1       2.41         2.28       2.24  -11.09  -13.67         2.41  0.00  0.75       -0.13
# 2       4.01         3.87       3.82  -10.69  -12.57         1.69  0.00  0.77       -0.14
# 3       4.01         3.87       3.83  -10.69  -12.57         1.69  0.00  0.77       -0.14
# 4       6.96         7.40       7.52   -9.43   -5.33        -3.54  0.00  0.79        0.44
# 5       8.98   9.46+0.00j       9.59   -9.21   -4.50  -4.09+0.01j  0.00  0.79  0.48+0.00j
# 6      11.70        12.13      12.28  -10.57   -5.28        -4.72  0.00  0.75        0.43
# 7      11.70  12.13+0.00j      12.28  -10.57   -5.28  -4.72+0.00j  0.00  0.75  0.43+0.00j
#
#
# kpoint: [-0.250, 0.250, 0.000], weight = 0.000000, spin: 0, energy units: eV (NB: bands start from zero)
# band      e0          qpe  qpe_diago   vxcme  sigxme    sigcmee0  vUme   ze0      qpeme0
# 0      -4.06  -3.96+0.11j      -3.90  -10.62  -16.26  5.81+0.17j  0.00  0.65  0.10+0.11j
# 1       0.42         0.30       0.26  -10.81  -14.35        3.38  0.00  0.72       -0.12
# 2       2.09         1.98       1.94  -10.07  -12.43        2.22  0.00  0.76       -0.11
# 3       4.59         4.44       4.39  -10.91  -12.69        1.58  0.00  0.77       -0.15
# 4       8.31         8.79       8.92   -9.60   -5.07       -3.92  0.00  0.79        0.48
# 5      10.71        11.19      11.33  -10.11   -4.84       -4.65  0.00  0.76        0.48
# 6      11.05        11.45      11.57  -10.23   -5.40       -4.31  0.00  0.77        0.40
# 7      11.99        12.39      12.53   -9.89   -4.36       -5.00  0.00  0.76        0.41
#
#
# 2       5.95         5.81       5.76  -11.25  -12.63        1.19  0.00  0.78       -0.15
# 3       5.95         5.81       5.76  -11.25  -12.63        1.19  0.00  0.78       -0.15
# 4       8.46         8.93       9.07  -10.04   -5.56       -3.88  0.00  0.78        0.47
# 5       8.46         8.93       9.07  -10.04   -5.56       -3.88  0.00  0.78        0.47
# 6       8.46         8.93       9.07  -10.04   -5.56       -3.88  0.00  0.78        0.47
# 7       9.20         9.66       9.80  -10.75   -5.73       -4.42  0.00  0.77        0.46

# %% [markdown]
# ## Convergence of the QP corrections

# %% [markdown]
# This example shows how to visualize the convergence of the QP results stored in the `SIGRES` produced by the $GW$ code (sigma run).

# %%
# List of SIGRES files computed with different values of nband.
filenames = [
    "si_g0w0ppm_nband10_SIGRES.nc",
    "si_g0w0ppm_nband20_SIGRES.nc",
    "si_g0w0ppm_nband30_SIGRES.nc",
]

filepaths = [abidata.ref_file(fname) for fname in filenames]

# Instantiate the plotter and add the filepaths to the plotter.
plotter = abilab.SigresPlotter()
plotter.add_files(filepaths)

# Plot the convergence of the QP gaps.
figure = plotter.plot_qpgaps(title="QP gaps vs sigma_nband", hspan=0.05)

# Plot the convergence of the QP energies.
#plotter.plot_qpenes(title="QP energies vs sigma_nband", hspan=0.05)
# Out:
# ksampling {'kptopt': None, 'shifts': None, 'kptrlatt': None, 'mpdivs': array([2, 2, 2], dtype=int32)}
# old_fermie 5.95851519733, new fermie 5.63275628022
# ksampling
#  {'kptopt': None, 'shifts': None, 'kptrlatt': None, 'mpdivs': array([2, 2, 2], dtype=int32)}
# old_fermie 5.95851519733, new fermie 5.63275628022
# ksampling
#  {'kptopt': None, 'shifts': None, 'kptrlatt': None, 'mpdivs': array([2, 2, 2], dtype=int32)}
# old_fermie 5.95851519733, new fermie 5.63275628022

# %%
# This examples shows how to plot the GW self-energy
# and the spectral function of Al at the gamma point (first band)
# See lesson tgw2_4
from abipy import abiopen
import abipy.data as abidata

sigma_file = abiopen(abidata.ref_file("tgw2_4o_SIGRES.nc"))

sigmaw = sigma_file.get_sigmaw(spin=0, kpoint=(0,0,0), band=0)

figure = sigmaw.plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-a15465286719> in <module>()
#       2 # and the spectral function of Al at the gamma point (first band)
#       3 # See lesson tgw2_4
# ----> 4 from abipy import abiopen
#       5 import abipy.data as abidata
#       6
#
# ImportError: cannot import name abiopen

# %%
# This examples shows how to plot the GW spectral functions A(w)
# See lesson tgw2_4
from abipy import abiopen
import abipy.data as data

# Open the file with the GW results
sigma_file = abiopen(data.ref_file("tgw2_4o_SIGRES.nc"))

# Plot A(w) for the first spin, the gamma point, and bands in [0,1,2,3]
sigma_file.plot_spectral_functions(spin=0, kpoint=(0,0,0), bands=range(0,4))
# Out:
# ksampling {'kptopt': None, 'shifts': None, 'kptrlatt': None, 'mpdivs': None}

# %% [markdown]
# ## Post processing tools for Bethe-Salpeter calculations

# %%
# Open the MDF file produced in the tutorial.
mdf_file = abiopen(abidata.ref_file("tbs_4o_DS2_MDF.nc"))

# Plot the imaginary part of the macroscopic dielectric function (EXC, RPA, GWRPA) between 2 and 5 eV.
title = "Si absorption spectrum: EXC vs RPA"
mdf_file.plot_mdfs(title=title, xlim=(2, 5))

# Plot the 6 different components of the macroscopic dielectric tensor 
#title = "Si macroscopic dielectric tensor (Reduced coord)"
#tensor_exc = mdf_file.get_tensor("exc")
#tensor_exc.symmetrize()
#tensor_exc.plot(title=title)

#title = "Si macroscopic dielectric tensor (Cartesian coord)"
#tensor_exc.plot(title=title,red_coords=False)
